# %%
import os
import pandas as pd

# %%
all_files = os.listdir(os.getcwd()+'\\data\\raw')
data_dict_ref = {'agecl': 'Age', 'all': 'All Families', 'edcl': 'Education', 
                 'famstruct': 'Family Structure', 'housecl': 'Housing Status',
                 'inccat': 'Income Percentile', 'nwcat': 'Net Worth Percentile',
                 'occat1': 'Employment Status', 'occat2': 'Occupation Type',
                 'racecl4': 'Race'
                }
all_csv_files = []
for f in all_files:
    if f.endswith('.csv'):
        all_csv_files.append(f)
all_csv_files
# Out:
# ['interactive_bulletin_charts_agecl_mean.csv',
#  'interactive_bulletin_charts_agecl_median.csv',
#  'interactive_bulletin_charts_all_mean.csv',
#  'interactive_bulletin_charts_all_median.csv',
#  'interactive_bulletin_charts_edcl_mean.csv',
#  'interactive_bulletin_charts_edcl_median.csv',
#  'interactive_bulletin_charts_famstruct_mean.csv',
#  'interactive_bulletin_charts_famstruct_median.csv',
#  'interactive_bulletin_charts_housecl_mean.csv',
#  'interactive_bulletin_charts_housecl_median.csv',
#  'interactive_bulletin_charts_inccat_mean.csv',
#  'interactive_bulletin_charts_inccat_median.csv',
#  'interactive_bulletin_charts_nwcat_mean.csv',
#  'interactive_bulletin_charts_nwcat_median.csv',
#  'interactive_bulletin_charts_occat1_mean.csv',
#  'interactive_bulletin_charts_occat1_median.csv',
#  'interactive_bulletin_charts_occat2_mean.csv',
#  'interactive_bulletin_charts_occat2_median.csv',
#  'interactive_bulletin_charts_racecl4_mean.csv',
#  'interactive_bulletin_charts_racecl4_median.csv',
#  'z1-nonfin-debt.csv']

# %%
master_df = pd.DataFrame()
mean_df = pd.DataFrame()
median_df = pd.DataFrame()
debt_data = all_csv_files.pop()

for filename in all_csv_files:
    category = filename.split('_')[3]
    df = pd.read_csv(os.getcwd()+'\\data\\raw\\'+filename, index_col='year')
    df['Categorization'] = data_dict_ref[category]
    if '_mean' in filename:
        df = df.add_suffix('_mean')
        mean_df = pd.concat([mean_df, df], axis=0)
    elif '_median' in filename:
        df = df.add_suffix('_median')
        median_df = pd.concat([median_df, df], axis=0)

# %%
master_df = pd.concat([master_df, mean_df, median_df], axis=1)
master_df.drop(columns=['Category_median'], inplace=True)
master_df.rename(columns={"Category_mean": "Category"}, inplace=True)
master_df.drop(columns=['Categorization_median'], inplace=True)
master_df.rename(columns={"Categorization_mean": "Categorization"}, inplace=True)

# %%
first_column = master_df.pop('Categorization')
master_df.insert(0, 'Categorization', first_column)

# %%
gdp_df = pd.read_csv(os.getcwd()+'\\data\\world_gdp\\API_NY.GDP.MKTP.CD_DS2_en_csv_v2_4150784.csv',  skiprows=3)
us_gdp_df = gdp_df[gdp_df['Country Name']=='United States']
world_gdp_df = gdp_df[gdp_df['Country Name']=='World']
world_gdp_df
# Out:
#     Country Name Country Code     Indicator Name  Indicator Code  \
# 259        World          WLD  GDP (current US$)  NY.GDP.MKTP.CD
#
#              1960          1961          1962          1963          1964  \
# 259  1.390298e+12  1.446418e+12  1.548223e+12  1.669094e+12  1.827514e+12
#
#              1965  ...          2013          2014          2015  \
# 259  1.990867e+12  ...  7.744323e+13  7.957553e+13  7.511714e+13
#
#              2016          2017          2018          2019          2020  \
# 259  7.631320e+13  8.122464e+13  8.627430e+13  8.756805e+13  8.474698e+13
#
#      2021  Unnamed: 66
# 259   NaN          NaN
#
# [1 rows x 67 columns]

# %%
master_df.head()
# Out:
#      Categorization      Category  Before_Tax_Income_mean  Net_Worth_mean  \
# year
# 1989            Age  Less than 35               55.509892       99.099434
# 1989            Age         35-44               98.887344      295.420260
# 1989            Age         45-54              120.250140      560.901000
# 1989            Age         55-64               94.909744      612.913090
# 1989            Age         65-74               71.143509      581.070860
#
#       Assets_mean  Financial_Assets_mean  Transaction_Accounts_mean  \
# year
# 1989    162.03719              39.419189                   8.064208
# 1989    400.74631             103.157810                  16.174339
# 1989    665.26245             190.108990                  34.650478
# 1989    691.87665             236.098110                  45.525204
# 1989    613.83185             247.993060                  46.005711
#
#       Certificates_of_Deposit_mean  Savings_Bonds_mean  \
# year
# 1989                     16.729122            2.346840
# 1989                     28.275034            3.825881
# 1989                     44.405811            5.566218
# 1989                     95.668076           14.797529
# 1989                     96.296051           24.618301
#
#       Directly_Held_Bonds_mean  ...  Other_Res_Real_Estate_Debt_median  \
# year                            ...
# 1989                 34.211586  ...                          34.806683
# 1989                179.602140  ...                          69.613365
# 1989                216.039550  ...                          39.779064
# 1989                173.570830  ...                          67.624405
# 1989                228.714520  ...                          27.845345
#
#       Installment_Loans_median  Other_Lines_of_Credit_median  \
# year
# 1989                  9.944766                      2.784534
# 1989                 13.922672                      5.966859
# 1989                 13.922672                      1.988953
# 1989                  7.955813                      3.977907
# 1989                  5.966859                      3.977907
#
#       Credit_Card_Balances_median  Other_Debt_median  \
# year
# 1989                     1.988953           1.591163
# 1989                     1.988953           1.988953
# 1989                     1.988953           5.966859
# 1989                     1.988953           5.966859
# 1989                     1.093924           3.977907
#
#       Mortgages_Home_Equity_Loans_median  Home_Equity_Lines_of_Credit_median  \
# year
# 1989                           87.513939                           37.790112
# 1989                           77.569176                           29.834297
# 1989                           49.723831                           41.768017
# 1989                           39.779064                           37.790112
# 1989                           19.889532                           13.922672
#
#       Vehicle_Installment_Loans_median  Education_Installment_Loans_median  \
# year
# 1989                          9.944766                            6.563546
# 1989                         13.266317                            3.977907
# 1989                         11.933719                            7.955813
# 1989                          9.944766                            3.977907
# 1989                          7.955813                            7.955813
#
#       Other_Installment_Loans_median
# year
# 1989                        1.988953
# 1989                        3.977907
# 1989                        4.574592
# 1989                        1.969064
# 1989                        1.690610
#
# [5 rows x 72 columns]

# %%
master_df['US_GDP'] = None
master_df['World_GDP'] = None
master_df
# Out:
#      Categorization             Category  Before_Tax_Income_mean  \
# year
# 1989            Age         Less than 35               55.509892
# 1989            Age                35-44               98.887344
# 1989            Age                45-54              120.250140
# 1989            Age                55-64               94.909744
# 1989            Age                65-74               71.143509
# ...             ...                  ...                     ...
# 2016           Race                Other               92.469833
# 2019           Race  White, non-Hispanic              122.499660
# 2019           Race  Black, non-Hispanic               59.598972
# 2019           Race             Hispanic               58.513363
# 2019           Race                Other              111.971430
#
#       Net_Worth_mean  Assets_mean  Financial_Assets_mean  \
# year
# 1989       99.099434    162.03719              39.419189
# 1989      295.420260    400.74631             103.157810
# 1989      560.901000    665.26245             190.108990
# 1989      612.913090    691.87665             236.098110
# 1989      581.070860    613.83185             247.993060
# ...              ...          ...                    ...
# 2016      486.788940    603.76910             237.081340
# 2019      980.549260   1101.41190             481.431090
# 2019      142.329740    206.96565              68.804108
# 2019      165.540990    244.59644              50.391312
# 2019      656.602660    788.31970             302.331600
#
#       Transaction_Accounts_mean  Certificates_of_Deposit_mean  \
# year
# 1989                   8.064208                     16.729122
# 1989                  16.174339                     28.275034
# 1989                  34.650478                     44.405811
# 1989                  45.525204                     95.668076
# 1989                  46.005711                     96.296051
# ...                         ...                           ...
# 2016                  36.084339                     69.917938
# 2019                  51.514420                    105.510320
# 2019                  13.268765                     39.633217
# 2019                  11.862248                     14.020637
# 2019                  43.891804                    120.870470
#
#       Savings_Bonds_mean  Directly_Held_Bonds_mean  ...  \
# year                                                ...
# 1989            2.346840                 34.211586  ...
# 1989            3.825881                179.602140  ...
# 1989            5.566218                216.039550  ...
# 1989           14.797529                173.570830  ...
# 1989           24.618301                228.714520  ...
# ...                  ...                       ...  ...
# 2016            4.507063               1437.112400  ...
# 2019            8.303209                673.580750  ...
# 2019            2.163269                       NaN  ...
# 2019            3.803653                       NaN  ...
# 2019           15.414285                426.950840  ...
#
#       Other_Lines_of_Credit_median  Credit_Card_Balances_median  \
# year
# 1989                      2.784534                     1.988953
# 1989                      5.966859                     1.988953
# 1989                      1.988953                     1.988953
# 1989                      3.977907                     1.988953
# 1989                      3.977907                     1.093924
# ...                            ...                          ...
# 2016                      1.223108                     2.520667
# 2019                      2.000000                     3.200000
# 2019                      3.500000                     1.300000
# 2019                      1.200000                     1.900000
# 2019                      1.000000                     2.400000
#
#       Other_Debt_median  Mortgages_Home_Equity_Loans_median  \
# year
# 1989           1.591163                           87.513939
# 1989           1.988953                           77.569176
# 1989           5.966859                           49.723831
# 1989           5.966859                           39.779064
# 1989           3.977907                           19.889532
# ...                 ...                                 ...
# 2016           7.445007                          154.218000
# 2019           7.500000                          138.000000
# 2019           2.300000                          118.000000
# 2019           4.200000                          131.000000
# 2019           3.000000                          178.000000
#
#       Home_Equity_Lines_of_Credit_median  Vehicle_Installment_Loans_median  \
# year
# 1989                           37.790112                          9.944766
# 1989                           29.834297                         13.266317
# 1989                           41.768017                         11.933719
# 1989                           37.790112                          9.944766
# 1989                           13.922672                          7.955813
# ...                                  ...                               ...
# 2016                           63.814346                         12.762869
# 2019                           24.000000                         14.000000
# 2019                           15.000000                         11.000000
# 2019                           13.000000                         14.000000
# 2019                           30.000000                         14.000000
#
#       Education_Installment_Loans_median  Other_Installment_Loans_median  \
# year
# 1989                            6.563546                        1.988953
# 1989                            3.977907                        3.977907
# 1989                            7.955813                        4.574592
# 1989                            3.977907                        1.969064
# 1989                            7.955813                        1.690610
# ...                                  ...                             ...
# 2016                           20.207876                        3.190717
# 2019                           23.000000                        4.800000
# 2019                           30.000000                        2.200000
# 2019                           17.600000                        3.000000
# 2019                           19.000000                        5.000000
#
#       US_GDP  World_GDP
# year
# 1989    None       None
# 1989    None       None
# 1989    None       None
# 1989    None       None
# 1989    None       None
# ...      ...        ...
# 2016    None       None
# 2019    None       None
# 2019    None       None
# 2019    None       None
# 2019    None       None
#
# [451 rows x 74 columns]

# %%
for i in master_df.index:
    master_df.at[i, 'US_GDP'] = us_gdp_df[str(i)].values[0]
    master_df.at[i, 'World_GDP'] = world_gdp_df[str(i)].values[0]
master_df.head()
# Out:
#      Categorization      Category  Before_Tax_Income_mean  Net_Worth_mean  \
# year
# 1989            Age  Less than 35               55.509892       99.099434
# 1989            Age         35-44               98.887344      295.420260
# 1989            Age         45-54              120.250140      560.901000
# 1989            Age         55-64               94.909744      612.913090
# 1989            Age         65-74               71.143509      581.070860
#
#       Assets_mean  Financial_Assets_mean  Transaction_Accounts_mean  \
# year
# 1989    162.03719              39.419189                   8.064208
# 1989    400.74631             103.157810                  16.174339
# 1989    665.26245             190.108990                  34.650478
# 1989    691.87665             236.098110                  45.525204
# 1989    613.83185             247.993060                  46.005711
#
#       Certificates_of_Deposit_mean  Savings_Bonds_mean  \
# year
# 1989                     16.729122            2.346840
# 1989                     28.275034            3.825881
# 1989                     44.405811            5.566218
# 1989                     95.668076           14.797529
# 1989                     96.296051           24.618301
#
#       Directly_Held_Bonds_mean  ...  Other_Lines_of_Credit_median  \
# year                            ...
# 1989                 34.211586  ...                      2.784534
# 1989                179.602140  ...                      5.966859
# 1989                216.039550  ...                      1.988953
# 1989                173.570830  ...                      3.977907
# 1989                228.714520  ...                      3.977907
#
#       Credit_Card_Balances_median  Other_Debt_median  \
# year
# 1989                     1.988953           1.591163
# 1989                     1.988953           1.988953
# 1989                     1.988953           5.966859
# 1989                     1.988953           5.966859
# 1989                     1.093924           3.977907
#
#       Mortgages_Home_Equity_Loans_median  Home_Equity_Lines_of_Credit_median  \
# year
# 1989                           87.513939                           37.790112
# 1989                           77.569176                           29.834297
# 1989                           49.723831                           41.768017
# 1989                           39.779064                           37.790112
# 1989                           19.889532                           13.922672
#
#       Vehicle_Installment_Loans_median  Education_Installment_Loans_median  \
# year
# 1989                          9.944766                            6.563546
# 1989                         13.266317                            3.977907
# 1989                         11.933719                            7.955813
# 1989                          9.944766                            3.977907
# 1989                          7.955813                            7.955813
#
#       Other_Installment_Loans_median           US_GDP              World_GDP
# year
# 1989                        1.988953  5641580000000.0  20171334961132.800781
# 1989                        3.977907  5641580000000.0  20171334961132.800781
# 1989                        4.574592  5641580000000.0  20171334961132.800781
# 1989                        1.969064  5641580000000.0  20171334961132.800781
# 1989                        1.690610  5641580000000.0  20171334961132.800781
#
# [5 rows x 74 columns]

# %%
master_df.to_csv('Masterdata.csv')
